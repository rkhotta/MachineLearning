# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.cluster import DBSCAN
from sklearn.preprocessing import StandardScaler

# %%
# Load your dataset (you can replace this with your own data)
# For demonstration purposes, I'll use a sample dataset
df = pd.read_csv("https://reneshbedre.github.io/assets/posts/tsne/tsne_scores.csv")

# %%
# Standardize the features (optional but recommended for DBSCAN)
scaler = StandardScaler()
df_scaled = scaler.fit_transform(df)

# %%
# Create a DBSCAN model
dbscan = DBSCAN(eps=0.5, min_samples=5)
labels = dbscan.fit_predict(df_scaled)

# %%
# Add the cluster labels to the original dataframe
df["Cluster"] = labels

# Visualize the clusters
plt.scatter(df["t-SNE-1"], df["t-SNE-2"], c=labels, cmap="viridis")
plt.xlabel("t-SNE-1")
plt.ylabel("t-SNE-2")
plt.title("DBSCAN Clustering")
plt.show()
